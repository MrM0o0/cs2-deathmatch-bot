# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp -r "/content/drive/MyDrive/cs2 character model recognition.v3i.yolov8" /content/dataset

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')
results = model.train(data='/content/dataset/data.yaml', epochs=100, imgsz=640, batch=16)

# %%
best_model = YOLO('/content/runs/detect/train/weights/best.pt')
best_model.export(format='onnx')

# %%
# !cp /content/runs/detect/train/weights/best.onnx "/content/drive/MyDrive/cs2_yolov8n_v3.onnx"
print('Done! ONNX model saved to your Google Drive as cs2_yolov8n_v3.onnx')
